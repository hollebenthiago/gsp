# %%
import pygsp as p
import numpy as np
import matplotlib.pyplot as plt
from ripser import ripser
from persim import plot_diagrams
import cv2

# %%
paths = ["imgs/im_proc/cameraman.jpg", "imgs/im_proc/pikachu.png", "imgs/im_proc/small_pikachu.png"]

# %%
def setup(path):
    
    image = np.flip(cv2.imread(path), axis = -1)
    sizex, sizey = np.shape(image)[:2]
    image_flatten = image.reshape(sizex * sizey, 3).T/255
    
    return image, image_flatten, (sizex, sizey)

def crop(image, x, y, t):
    
    crop_image = image[y : y + t, x : x + t]
    crop_image_flatten = crop_image.reshape(t * t, 3).T/255
    
    return crop_image, crop_image_flatten

def make_noisy_image(path, mu = 0, sigma = 0.2):
    
    image, image_flatten, sizes = setup(path)
    sizex, sizey = np.shape(image)[:2]
    
    r_noisy = image_flatten[0] + np.random.normal(mu, sigma, size = len(image_flatten[0]))
    b_noisy = image_flatten[1] + np.random.normal(mu, sigma, size = len(image_flatten[2])) ## indices trocados para converter rgb em rbg
    g_noisy = image_flatten[2] + np.random.normal(mu, sigma, size = len(image_flatten[1])) ## indices trocados para converter rgb em rbg
    
    noises = np.array([r_noisy, b_noisy, g_noisy])
    image_noisy = noises.T.reshape(sizex, sizey, 3)
    
    return image_noisy, noises

# %%
i, x, y, t = 2, 65, 20, 10
mu, sigma = 0, 0.1

image, image_flatten, (sizex, sizey) = setup(paths[i])
crop_image, crop_image_flatten = crop(image, x, y, t)

image_noisy, noises = make_noisy_image(paths[i], mu, sigma)
crop_image_noisy, crop_image_noisy_flatten = crop(image_noisy, x, y, t)

# %%
titles = [['original image', 'noisy image'], ['cropped original image', 'cropped noisy image']]

fig, ax = plt.subplots(2, 2, figsize=(12, 8))
# fig, ax = plt.subplots(1, 3, figsize=(12, 8))
ax[0][0].imshow(image)
ax[1][0].imshow(crop_image)
ax[1][1].imshow(crop_image_noisy)
ax[0][1].imshow(image_noisy)

for i in [0,1]:
    for j in [0,1]:
        ax[i][j].axis('off')
        ax[i][j].set_title(titles[i][j])
# ax[2].axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# G = p.graphs.Grid2d(t, t)
G = p.graphs.Grid2d(sizex, sizey)
tau = 2
def h(x):
    return 1. / (1. + tau * x)
g = p.filters.Filter(G, h)

# np.shape(crop_image_flatten[0]), np.shape(r_noisy)

# %%
# %%time
G.estimate_lmax() # estimar para evitar calcular a base ortonormal da TdF
# Out:
# CPU times: user 78.1 ms, sys: 0 ns, total: 78.1 ms
# Wall time: 16.8 ms

# %%
# %%time
r_denoised, g_denoised, b_denoised = g.filter(noises[0]), g.filter(noises[1]), g.filter(noises[2])
# Out:
# CPU times: user 15.6 ms, sys: 0 ns, total: 15.6 ms
# Wall time: 8.2 ms

# %%
image_denoised = np.array([r_denoised, g_denoised, b_denoised]).T.reshape(sizex, sizey, 3)
crop_image_denoised, crop_image_denoised_flatten = crop(image_denoised, x, y, t)

# %%
titles = [['original image', 'noisy image', 'denoised image'], ['cropped original image', 'cropped noisy image', 'cropped denoised image']]
imgs = [[image, image_noisy, image_denoised], [crop_image, crop_image_noisy, crop_image_denoised]]
fig, ax = plt.subplots(2, 3, figsize = (18, 9))

for i in [0,1]:
    for j in [0,1, 2]:
        ax[i][j].imshow(imgs[i][j])
        ax[i][j].axis('off')
        ax[i][j].set_title(titles[i][j])
fig.suptitle('Usual grid graph')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
xs = np.linspace(0, 1, sizex)
ys = np.linspace(0, 1, sizey)
# full coorindate arrays
data = np.rot90(np.array(np.meshgrid(ys, xs)).T, k = 1)
data = data.reshape(sizex * sizey, 2)

# %%
# %%time
diagrams = ripser(data, thresh=1)['dgms'] #thresh é maior valor de epsilon que a função considera
# Out:
# CPU times: user 4min 41s, sys: 3 s, total: 4min 44s
# Wall time: 4min 45s

# %%
plot_diagrams(diagrams)

# %%
# eps = np.sqrt((1 / sizex) ** 2 + (1 / sizey) ** 2)
eps = 0.02301448

# %%
gray_image = scv2.cvtColor(image, cv2.COLOR_BGR2GRAY)/255
gray_signal = gray_image.reshape(sizex * sizey)
noisy_gray_signal = gray_signal + np.random.normal(mu, sigma, size = sizex * sizey)

# %%
x=np.linspace(0,5,100)
y=np.sin(x)
fig=plt.figure()
plt.ion()
plt.plot(x, y)
plt.title("Plot generated using Matplotlib")
plt.xlabel("x")
plt.ylabel("sinx")

# %%
plt.imshow(gray_image)

# %%
1/(2 * sizey), 1/sizex
# Out:
# (0.005263157894736842, 0.02)

# %%
np.shape(gray_image), np.shape(gray_signal)
# Out:
# ((50, 95), (4750,))

# %%
G.Ne
# Out:
# 9355

# %%
# 4700, 14005

# %%
1/sizey
# Out:
# 0.010526315789473684

# %%
# for i, eps in enumerate(np.arange(1.1/sizey, 0.2, 1/sizey)):
for i, eps in enumerate([1/sizey + 1e-3, 1/sizex + 1e-3, np.sqrt((1/sizey) ** 2 + (1/sizex) ** 2) + 1e-7]):
    print(i, eps)
    L = p.graphs.NNGraph(Xin = data, NNtype = 'radius', epsilon = eps, center = False, rescale = False)
    L.estimate_lmax()
    l = p.filters.Filter(L, h)
    denoised_gray_signal = l.filter(noisy_gray_signal)
    plt.ion()
    fig, ax = plt.subplots(1, 3, figsize=(15,5))
    ax[0].imshow(gray_signal.reshape(sizex, sizey))
    ax[1].imshow(noisy_gray_signal.reshape(sizex, sizey))
    ax[2].imshow(denoised_gray_signal.reshape(sizex, sizey))
    titles = ['original gray image', 'noisy image', 'filtered image' + '\n' 'graph has ' + str(L.Ne) + ' edges' + '\n' 'max difference between denoised signal and original signal is ' + str(np.linalg.norm(denoised_gray_signal - gray_signal))]
    for j in [0,1,2]:
        ax[j].axis('off')
        ax[j].set_title(titles[j])
    plt.savefig("imgs/test2/a" + str(i) )
    plt.close(fig)
# Out:
# 0 0.011526315789473683
# 1 0.021
# 2 0.022601058477456724

# %%
# %%time
L = p.graphs.NNGraph(Xin = data, NNtype = 'radius', epsilon = 0.01, center = False, rescale = False)
# Out:
# CPU times: user 453 ms, sys: 0 ns, total: 453 ms
# Wall time: 444 ms

# %%
L.plot_signal(gray_image.reshape(sizex * sizey))

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
G.plot_signal(gray_image.reshape(sizex * sizey), ax = ax)

# %%
fig, ax = plt.subplots(1,1,figsize=(15,15))
L.plot_signal(gray_image.reshape(50 * 95), ax = ax)

# %%
plt.imshow(gray_image)
plt.axis('off')
plt.show()

# %%
l = p.filters.Filter(L, h)

# %%
diagrams = ripser(data, thresh=1)['dgms'] #thresh é maior valor de epsilon que a função considera
plot_diagrams(diagrams,show=True)

# %%
dx =

# %%
np.shape(data)[0]
# Out:
# 255

# %%
plt.scatter(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-864e67bb4752> in <module>
# ----> 1 plt.matshow(data)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in matshow(A, fignum, **kwargs)
#    2299         fig = figure(fignum, figsize=figaspect(A))
#    2300         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
# -> 2301     im = ax.matshow(A, **kwargs)
#    2302     sci(im)
#    2303     return im
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in matshow(self, Z, **kwargs)
#    7756               'aspect': 'equal',          # (already the imshow default)
#    7757               **kwargs}
# -> 7758         im = self.imshow(Z, **kw)
#    7759         self.title.set_y(1.05)
#    7760         self.xaxis.tick_top()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     707         if not (self._A.ndim == 2
#     708                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 709             raise TypeError("Invalid shape {} for image data"
#     710                             .format(self._A.shape))
#     711
#
# TypeError: Invalid shape (255, 489, 2) for image data

# %%
# denoised_crop_image = np.array([r_denoised, b_denoised, g_denoised]).T.reshape(t, t, 3)
denoised_image = np.array([r_denoised, b_denoised, g_denoised]).T.reshape(sizex, sizey, 3)

fig, ax = plt.subplots(1, 3, figsize = (18, 18))

# ax[0].imshow(crop_image)
ax[0].imshow(image)
ax[0].axis('off')
ax[0].set_title('original image')

# ax[1].imshow(crop_image_noisy)
ax[1].imshow(image_noisy)
ax[1].axis('off')
ax[1].set_title('noisy image')

# ax[2].imshow(denoised_crop_image)
ax[2].imshow(denoised_image)
ax[2].axis('off')
ax[2].set_title('denoised image')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
max(np.abs(r_noisy - image_flatten[0])), max(np.abs(g_noisy - image_flatten[2])), max(np.abs(b_noisy - image_flatten[1]))
# Out:
# (0.9052855835413164, 0.8908173177707268, 0.9209389640718725)

# %%
max(np.abs(r_denoised - image_flatten[0])), max(np.abs(g_denoised - image_flatten[2])), max(np.abs(b_denoised - image_flatten[1]))
# Out:
# (0.40093043810514284, 0.33072413358623914, 0.42706626280272264)

# %%
#definir grafo diferente com diagonais entre pixels

# %%
M = G.W

# %%
O = np.zeros(np.shape(G.W))

# %%
n = t
x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)
# full coorindate arrays
data = np.array(np.meshgrid(x, y)).T

# %%
data = data.reshape(n ** 2, 2)
data
# Out:
# array([[0.        , 0.        ],
#        [0.        , 0.01265823],
#        [0.        , 0.02531646],
#        ...,
#        [1.        , 0.97468354],
#        [1.        , 0.98734177],
#        [1.        , 1.        ]])

# %%
1/(n - 1) * np.sqrt(2)
# Out:
# 0.01790143749839361

# %%
L = p.graphs.NNGraph(Xin = data, NNtype = 'radius', epsilon = 1/(n - 1) * np.sqrt(2), center = False, rescale = False)
l = p.filters.Filter(L, h)

# %%
L.plot_signal(np.rot90(r_denoised.reshape(t, t), k = 3).reshape(t ** 2))
plt.axis('off')
# Out:
# (-0.05, 1.05, -0.05, 1.05)

# %%
# %%time
L.compute_fourier_basis()
# Out:
# 2022-05-08 03:43:45,677:[WARNING](pygsp.graphs.graph.compute_fourier_basis): Computing the full eigendecomposition of a large matrix (6400 x 6400) may take some time.
# CPU times: user 2min 31s, sys: 4.48 s, total: 2min 35s
# Wall time: 22.5 s

# %%
# %%time
new_r_denoised, new_g_denoised, new_b_denoised = l.filter(r_noisy, method='exact'), l.filter(g_noisy, method='exact'), l.filter(b_noisy, method='exact')
# Out:
# CPU times: user 969 ms, sys: 734 ms, total: 1.7 s
# Wall time: 1.04 s

# %%
max(np.abs(r_denoised - crop_image_flatten[0])), max(np.abs(new_r_denoised - crop_image_flatten[0]))
# Out:
# (0.42992492712926667, 0.48417918196462034)

# %%
fig, ax = plt.subplots(1,3, figsize = (18,5))
L.plot_signal(np.rot90(new_r_denoised.reshape(t, t), k = 3).reshape(t ** 2), ax = ax[0])
G.plot_signal(np.rot90(r_denoised.reshape(t, t), k = 4).reshape(t ** 2), ax = ax[1])
L.plot_signal(np.rot90(new_r_denoised.reshape(t, t), k = 3).reshape(t ** 2)-np.rot90(r_denoised.reshape(t, t), k = 4).reshape(t ** 2), ax = ax[2])
ax[0].axis('off')
ax[1].axis('off')
ax[2].axis('off')
# Out:
# (-0.05, 1.05, -0.05, 1.05)
