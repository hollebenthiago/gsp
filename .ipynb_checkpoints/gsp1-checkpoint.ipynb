# %%
import pygsp as p
import numpy as np
import matplotlib.pyplot as plt

# %%
# função que define os dados
def start_points(n = 100, r = 1, eps = 0.2):
    ps = []
    n = 100
    for i in range(n):
        theta = np.random.uniform(0, 2 * np.pi)
        eps = np.random.uniform(-0.2, 0.2)
        x, y  = (r + eps) * np.cos(theta), (r + eps) * np.sin(theta)
        ps += [[x,y]]
    return np.array([np.array(q) for q in ps])

# %%
ps = start_points()

# %%
# verificando que os pontos estão perto de um círculo
fig, ax = plt.subplots(figsize = (8,8))
ax.scatter([q[0] for q in ps], [q[1] for q in ps])
ax.plot(np.linspace(-1,1), np.sqrt(1 - np.linspace(-1, 1) ** 2), '--', color = 'tab:blue')
ax.plot(np.linspace(-1,1), -np.sqrt(1 - np.linspace(-1, 1) ** 2), '--', color = 'tab:blue')
plt.show()

# %%
# definindo um sinal constante = a, o sinal da função é a função que vale a + ruído entre -r e r
def random_signal(ps, a, r):
    s = a * np.ones(len(ps)) + np.random.uniform(-r, r, size = len(ps))
    return s

# %%
s = random_signal(ps, 10, 5)

# %%
#definindo o grafo NN tipo radial nos pontos definidos acima com epsilon = eps
eps = 0.8
G = p.graphs.NNGraph(Xin = ps, NNtype = 'radius', epsilon = eps)

# %%
G.is_connected()
# Out:
# True

# %%
fig, ax = plt.subplots(1, 2, figsize = (24, 9))
ax[0].spy(G.W, markersize=5)
# G.plot(ax=axes[1])
G.plot_signal(s, ax=ax[1])

ax[0].set_title("adjacency matrix of G")
plt.show()

# %%
G.compute_fourier_basis() #calculando a matriz de autovetores U

# %%
s_hat = G.gft(s) # transformada de fourier 
s_star = G.igft(s_hat) #transformada da matriz inversa
max(s - s_star) #boa aproximação
# Out:
# 1.5987211554602254e-14

# %%
fig, ax = plt.subplots(1, 2, figsize = (25, 9))
#plotando s_hat
for i,si in enumerate(s_hat):
    ax[0].plot([i, i],[0, si], color = 'tab:blue')
ax[0].scatter(np.arange(len(s_hat)), s_hat)
ax[0].plot([0, len(s_hat) - 1], [0, 0])
#plotando s
G.plot_signal(s, ax = ax[1])

ax[0].set_title(r'$\hat s$: signal in the spectral domain', )

fig.suptitle(r'$\varepsilon = 0.0$' + str(1), fontsize = 15)
# plt.savefig('imgs/' + str(int(eps * 100))) #descomentar para salvar imagem
plt.show()

# %%
## código para salvar as imagens para fazer um gif
# for j, eps in enumerate(np.arange(0.01, 1, 0.01)):
#     G = p.graphs.NNGraph(Xin = ps, NNtype = 'radius', epsilon = eps)
#     G.compute_fourier_basis()
#     s_hat = G.gft(s)
# #     s_star = G.igft(s_hat)
#     fig, ax = plt.subplots(1, 2, figsize = (25, 9))
#     for i,si in enumerate(s_hat):
#         ax[0].plot([i, i],[0, si], color = 'tab:blue')
#     #     ax[0].scatter([i, i],[0, si], color = 'tab:blue')
#     # ax[0].scatter([[i, s[0]] for i, s in enumerate(s_hat)])
#     ax[0].scatter(np.arange(len(s_hat)), s_hat)
#     ax[0].plot([0, len(s_hat) - 1], [0, 0])
#     # ax[0].plot(np., s_hat, 'o')
#     # ax[0].plot(s_hat, 'o')
#     G.plot_signal(s, ax = ax[1])

#     fig.suptitle(r'$\varepsilon = $' + str(np.round(eps, 2)), fontsize = 15)
    
#     ax[0].set_title(r'$\hat s$: signal in the spectral domain', )
#     plt.savefig('imgs/' + str(j + 1))

# %%
import imageio

# %%
## usar as imagens salvas acima para fazer um gif
# images = []
# filenames = ['imgs/' + str(i) + '.png' for i in range(1, 100)]
# for filename in filenames:
#     images.append(imageio.imread(filename))
# imageio.mimsave('gifs/tdagft.gif', images)

# %%
np.max(G.U[-1])
# Out:
# 0.6245757171668624

# %%
G.plot_signal(G.U[15])
